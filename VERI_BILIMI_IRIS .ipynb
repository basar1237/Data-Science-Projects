# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
# %matplotlib inline

df=pd.read_csv("/kaggle/input/iris-flower-dataset/IRIS.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df["species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.corr()
# Out:
# /tmp/ipykernel_32/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
corr=df.corr()
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values);
# Out:
# /tmp/ipykernel_32/744324435.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()

# %%
df["species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df["species"].nunique()
# Out:
# 3

# %%
sns.scatterplot(x="sepal_width",y="sepal_length",data=df,color="green");

# %%
sns.jointplot(x="sepal_width",y="sepal_length",data=df,color="green");

# %%
sns.scatterplot(x="sepal_width",y="sepal_length",hue="species",data=df,color="green");

# %%
df["species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
sns.violinplot(y="sepal_width",data=df,color="yellow");

# %%
sns.displot(df["sepal_width"],bins=10,kde=True);

# %%
sns.violinplot(x="species",y="sepal_length",data=df);

# %%
sns.countplot(x="species",data=df);

# %%
sns.jointplot(x="sepal_length",y="sepal_width",data=df);

# %%
sns.jointplot(x=df["sepal_length"],y=df["sepal_width"],data=df,kind="kde");

# %%
sns.scatterplot(x="petal_length",y="petal_width",data=df);

# %%
 df.corr()["petal_length"]["petal_width"]
# Out:
# /tmp/ipykernel_32/2912387115.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()["petal_length"]["petal_width"]
# 0.9627570970509662

# %%
 df["total_length"]=df["petal_length"]+df["sepal_length"]

# %%
df["total_length"].mean()
# Out:
# 9.602

# %%
df["total_length"].std()
# Out:
# 2.5191739884121973

# %%
df["total_length"].max()
# Out:
# 14.600000000000001

# %%
df[(df["sepal_length"]>5.5)&(df["species"]=="Setosa")]
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species, total_length]
# Index: []

# %%
df[(df["petal_length"]<5)&(df["species"]=="Virginicia")][["sepal_length","sepal_width"]]
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width]
# Index: []

# %%
df.groupby(["species"]).mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width  \
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026
#
#                  total_length
# species
# Iris-setosa             6.470
# Iris-versicolor        10.196
# Iris-virginica         12.140

# %%
df.groupby(["species"])["petal_length"].std()
# Out:
# species
# Iris-setosa        0.173511
# Iris-versicolor    0.469911
# Iris-virginica     0.551895
# Name: petal_length, dtype: float64
