# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno

# %%
df=pd.read_csv("zomato_dataset.csv")
df.head()
# Out:
#   Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0      Doner King            3.9              4.2            39
# 1      Doner King            3.9              4.2            39
# 2      Doner King            3.9              4.2            39
# 3      Doner King            3.9              4.2            39
# 4      Doner King            3.9              4.2            39
#
#    Delivery Votes   Cuisine  Place Name        City                 Item Name  \
# 0               0  Fast Food   Malakpet   Hyderabad       Platter Kebab Combo
# 1               0  Fast Food   Malakpet   Hyderabad   Chicken Rumali Shawarma
# 2               0  Fast Food   Malakpet   Hyderabad    Chicken Tandoori Salad
# 3               0  Fast Food   Malakpet   Hyderabad         Chicken BBQ Salad
# 4               0  Fast Food   Malakpet   Hyderabad  Special Doner Wrap Combo
#
#   Best Seller  Votes  Prices
# 0  BESTSELLER     84   249.0
# 1  BESTSELLER     45   129.0
# ...

# %%
df.shape
# Out:
# (123657, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123657 entries, 0 to 123656
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Restaurant Name  123657 non-null  object
#  1   Dining Rating    91421 non-null   float64
#  2   Delivery Rating  122377 non-null  float64
#  3   Dining Votes     123657 non-null  int64
#  4   Delivery Votes   123657 non-null  int64
#  5   Cuisine          123657 non-null  object
#  6   Place Name       123657 non-null  object
#  7   City             123657 non-null  object
#  8   Item Name        123657 non-null  object
#  9   Best Seller      27942 non-null   object
#  10  Votes            123657 non-null  int64
#  11  Prices           123657 non-null  float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 11.3+ MB

# %%
df.describe().T
# Out:
#                     count        mean         std   min    25%     50%    75%  \
# Dining Rating     91421.0    3.822264    0.408693  2.50    3.6    3.90    4.1
# Delivery Rating  122377.0    3.963184    0.245900  2.50    3.8    4.00    4.1
# Dining Votes     123657.0  152.729858  232.214061  0.00    0.0   30.00  217.0
# Delivery Votes   123657.0  115.763725  243.970828  0.00    0.0    0.00   23.0
# Votes            123657.0   24.666772  125.236009  0.00    0.0    0.00   15.0
# Prices           123657.0  241.378399  192.830713  0.95  130.0  208.57  299.0
#
#                      max
# Dining Rating        4.8
# Delivery Rating      4.6
# Dining Votes       997.0
# Delivery Votes     983.0
# Votes             9750.0
# Prices           12024.0

# %%
df.isnull().sum()
# Out:
# Restaurant Name        0
# Dining Rating      32236
# Delivery Rating     1280
# Dining Votes           0
# Delivery Votes         0
# Cuisine                0
# Place Name             0
# City                   0
# Item Name              0
# Best Seller        95715
# Votes                  0
# Prices                 0
# dtype: int64

# %%
msno.bar(df);

# %%
msno.matrix(df);

# %%
msno.heatmap(df);

# %%
df.corr()
# Out:
# /var/folders/_b/1x9hj_s15m1c7h3jnj7x41mh0000gn/T/ipykernel_17766/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  Dining Rating  Delivery Rating  Dining Votes  Delivery Votes  \
# Dining Rating         1.000000         0.311651      0.229514       -0.138843
# Delivery Rating       0.311651         1.000000      0.132089       -0.065398
# Dining Votes          0.229514         0.132089      1.000000       -0.244525
# Delivery Votes       -0.138843        -0.065398     -0.244525        1.000000
# Votes                 0.040707         0.049216      0.007271       -0.063766
# Prices                0.074197         0.054198      0.016136        0.007060
#
#                     Votes    Prices
# Dining Rating    0.040707  0.074197
# Delivery Rating  0.049216  0.054198
# ...

# %%
df.head()
# Out:
#   Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0      Doner King            3.9              4.2            39
# 1      Doner King            3.9              4.2            39
# 2      Doner King            3.9              4.2            39
# 3      Doner King            3.9              4.2            39
# 4      Doner King            3.9              4.2            39
#
#    Delivery Votes   Cuisine  Place Name        City                 Item Name  \
# 0               0  Fast Food   Malakpet   Hyderabad       Platter Kebab Combo
# 1               0  Fast Food   Malakpet   Hyderabad   Chicken Rumali Shawarma
# 2               0  Fast Food   Malakpet   Hyderabad    Chicken Tandoori Salad
# 3               0  Fast Food   Malakpet   Hyderabad         Chicken BBQ Salad
# 4               0  Fast Food   Malakpet   Hyderabad  Special Doner Wrap Combo
#
#   Best Seller  Votes  Prices
# 0  BESTSELLER     84   249.0
# 1  BESTSELLER     45   129.0
# ...

# %%
 df["Restaurant Name"].nunique()
# Out:
# 826

# %%
 df["Cuisine "].unique()
# Out:
# array(['Fast Food', 'Wraps', 'Biryani', 'Chinese', 'Beverages',
#        'Desserts', 'Shake', 'Mandi', 'South Indian', 'Kebab', 'Pizza',
#        'Bakery', 'Ice Cream', 'Mughlai', 'North Indian', 'Momos',
#        'Shawarma', 'Burger', 'Turkish', 'Rolls', 'Coffee', 'Seafood',
#        'Hyderabadi', 'Salad', 'Sichuan', 'Sandwich', 'Italian',
#        'Lucknowi', 'Continental', 'American', 'Mexican', 'Kerala', 'BBQ',
#        'Rajasthani', 'Healthy Food', 'Tibetan', 'Street Food', 'Mithai',
#        'Juices', 'Maharashtrian', 'Thai', 'Vietnamese', 'Pasta',
#        'Gujarati', 'Kathiyawadi', 'Andhra', 'Awadhi', 'Tea'], dtype=object)

# %%
df["City"].unique()
# Out:
# array([' Hyderabad', ' Mumbai', ' Chennai', ' Pune', ' Jaipur', ' Kochi',
#        ' Goa', ' Bangalore', ' Kolkata', ' Ahmedabad', ' Banaswadi',
#        ' Ulsoor', ' Malleshwaram', ' Magrath Road', ' Lucknow',
#        ' New Delhi', ' Raipur'], dtype=object)

# %%
df.groupby("City")["Dining Votes"].count()
# Out:
# City
#  Ahmedabad       10178
#  Banaswadi          97
#  Bangalore       12040
#  Chennai         13100
#  Goa              2360
#  Hyderabad       15613
#  Jaipur          14438
#  Kochi            7759
#  Kolkata          8662
#  Lucknow          6455
#  Magrath Road       54
#  Malleshwaram       43
#  Mumbai          13535
#  New Delhi        3490
#  Pune             8067
#  Raipur           7700
#  Ulsoor             66
# Name: Dining Votes, dtype: int64

# %%
df.groupby(["City", "Place Name"])["Dining Rating"].value_counts()
# Out:
# City        Place Name   Dining Rating
#  Ahmedabad  Ambavadi     3.900000         232
#                          4.200000         159
#             Ashram Road  3.800000         129
#             Astodia      3.822264          26
#             Bapunagar    3.700000         151
#                                          ...
#  Raipur     Tatibandh    4.000000         462
#                          3.822264         249
#             Tikrapara    3.822264          91
#                          3.800000          61
#  Ulsoor     Lido Mall    3.822264          66
# Name: Dining Rating, Length: 722, dtype: int64

# %%
df.isnull().sum()
# Out:
# Restaurant Name    0
# Dining Rating      0
# Delivery Rating    0
# Dining Votes       0
# Delivery Votes     0
# Cuisine            0
# Place Name         0
# City               0
# Item Name          0
# Best Seller        0
# Votes              0
# Prices             0
# dtype: int64

# %%
df.head()
# Out:
#   Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0      Doner King            3.9              4.2            39
# 1      Doner King            3.9              4.2            39
# 2      Doner King            3.9              4.2            39
# 3      Doner King            3.9              4.2            39
# 4      Doner King            3.9              4.2            39
#
#    Delivery Votes   Cuisine  Place Name        City                 Item Name  \
# 0               0  Fast Food   Malakpet   Hyderabad       Platter Kebab Combo
# 1               0  Fast Food   Malakpet   Hyderabad   Chicken Rumali Shawarma
# 2               0  Fast Food   Malakpet   Hyderabad    Chicken Tandoori Salad
# 3               0  Fast Food   Malakpet   Hyderabad         Chicken BBQ Salad
# 4               0  Fast Food   Malakpet   Hyderabad  Special Doner Wrap Combo
#
#   Best Seller  Votes  Prices
# 0  BESTSELLER     84   249.0
# 1  BESTSELLER     45   129.0
# ...

# %%
df["Dining Rating"].fillna(df["Dining Rating"].mean(),inplace=True)

# %%
df["Delivery Rating"].fillna(df["Delivery Rating"].mean(),inplace=True)

# %%
df["Best Seller"].value_counts()
# Out:
# BESTSELLER                  112707
# MUST TRY                      4151
# Not eligible for coupons      2440
# CHEF'S SPECIAL                1822
# SPICY                         1254
# Not on Pro                     657
# NEW                            455
# SEASONAL                        91
# Eggless available               34
# VEGAN                           26
# GLUTEN FREE                      9
# FODMAP FRIENDLY                  9
# DAIRY FREE                       2
# Name: Best Seller, dtype: int64

# %%
df["Best Seller"].isnull().sum()
# Out:
# 0

# %%
df['Best Seller'].fillna(df['Best Seller'].mode()[0], inplace=True)

# %%
import matplotlib.pyplot as plt

counts = df["Best Seller"].value_counts()
labels = ["BESTSELLER", "MUST TRY", "Not eligible for coupons", "CHEF'S SPECIAL", "SPICY", "Not on Pro", "NEW", "SEASONAL", "Eggless available", "VEGAN", "GLUTEN FREE", "FODMAP FRIENDLY", "DAIRY FREE"]

plt.pie(counts, labels=labels)

plt.show()

# %%
df_k=df.copy()
df_k.head()
# Out:
#   Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0      Doner King            3.9              4.2            39
# 1      Doner King            3.9              4.2            39
# 2      Doner King            3.9              4.2            39
# 3      Doner King            3.9              4.2            39
# 4      Doner King            3.9              4.2            39
#
#    Delivery Votes   Cuisine  Place Name        City                 Item Name  \
# 0               0  Fast Food   Malakpet   Hyderabad       Platter Kebab Combo
# 1               0  Fast Food   Malakpet   Hyderabad   Chicken Rumali Shawarma
# 2               0  Fast Food   Malakpet   Hyderabad    Chicken Tandoori Salad
# 3               0  Fast Food   Malakpet   Hyderabad         Chicken BBQ Salad
# 4               0  Fast Food   Malakpet   Hyderabad  Special Doner Wrap Combo
#
#   Best Seller  Votes  Prices
# 0  BESTSELLER     84   249.0
# 1  BESTSELLER     45   129.0
# ...

# %%
df['Delivery Rating'].unique()
# Out:
# array([4.2       , 3.7       , 4.        , 3.9       , 4.1       ,
#        3.5       , 4.3       , 3.8       , 3.3       , 3.96318426,
#        4.5       , 3.6       , 4.6       , 3.2       , 4.4       ,
#        3.4       , 3.1       , 3.        , 2.5       ])

# %%
df['Best Seller'].unique()
# Out:
# array(['BESTSELLER', 'MUST TRY', "CHEF'S SPECIAL", 'SEASONAL',
#        'Not eligible for coupons', 'VEGAN', 'Not on Pro', 'SPICY', 'NEW',
#        'GLUTEN FREE', 'DAIRY FREE', 'FODMAP FRIENDLY',
#        'Eggless available'], dtype=object)

# %%
location_counts=df['City'].value_counts().head(10)

# %%
plt.figure(figsize=(8, 6))
location_counts.plot(kind='bar', color='lightgray', edgecolor='black')
plt.xlabel('Location', fontsize=12)
plt.ylabel('Number of Restaurants', fontsize=12)
plt.title('Top Locations with Highest Number of Restaurants', fontsize=14);

# %%
restaurant_ratings = df.groupby('Restaurant Name')['Dining Rating'].mean().reset_index()

# %%
sorted_df = restaurant_ratings.sort_values('Dining Rating', ascending=False)

# %%
top_10_restaurants = sorted_df.head(10)

# %%
restaurant_names = top_10_restaurants['Restaurant Name']
dining_ratings = top_10_restaurants['Dining Rating']

# %%
plt.figure(figsize=(8, 8))
_, _, autotexts = plt.pie(dining_ratings, labels=restaurant_names, startangle=90, autopct='', textprops={'fontsize': 10})
plt.title('Top 10 Restaurant by Dining Rating', fontsize=24);
plt.tight_layout()
plt.show()

# %%
restaurant_ratings = df.groupby('Restaurant Name')['Delivery Rating'].mean().reset_index()

# %%
sorted_df = restaurant_ratings.sort_values('Delivery Rating', ascending=False)

# %%
op_10_restaurants = sorted_df.head(10)

# %%
restaurant_names = top_10_restaurants['Restaurant Name']

# %%
plt.figure(figsize=(9, 9))
_, _, autotexts = plt.pie(dining_ratings, labels=restaurant_names, startangle=90,autopct='', textprops={'fontsize': 10})
plt.title('Top 10 Restaurant by Delivery Rating', fontsize=14);

# %%
chicken_biryani_df = df[df['Item Name'] == 'Chicken Biryani']

# %%
location_ratings = chicken_biryani_df.groupby('Place Name')['Dining Rating'].mean()

# %%
sorted_locations = location_ratings.sort_values(ascending=False)

# %%
top_locations = sorted_locations.head(20)
print(top_locations)
# Out:
# Place Name
# Dadar West          4.50
# Kaiserbagh          4.50
# Mall De Goa         4.40
# Majestic            4.40
# Shankar Nagar       4.30
# Residency Road      4.30
# Mansarovar          4.30
# Ghansi Bazaar       4.30
# Park Circus Area    4.20
# New Market Area     4.20
# Nallakunta          4.20
# Mehdipatnam         4.20
# Meerpet             4.20
# Masab Tank          4.20
# Somajiguda          4.20
# Gomti Nagar         4.20
# Abids               4.20
# T. Nagar            4.15
# MI Road             4.10
# Royapettah          4.10
# Name: Dining Rating, dtype: float64

# %%
chicken_biryani_df = df[df['Item Name'] == 'Chicken Biryani']

# %%
location_ratings = chicken_biryani_df.groupby('Place Name')['Dining Rating'].mean()

# %%
sorted_locations = location_ratings.sort_values(ascending=False)

# %%
top_20_locations = sorted_locations[:20]

# %%
plt.figure(figsize=(12, 8))
plt.barh(top_20_locations.index, top_20_locations.values, color='brown')
plt.xlabel('Average Rating')
plt.ylabel('Location')
plt.title('Top 20 Location with the Highest Average Rating for Chicken Biryani')

plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#   Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0      Doner King            3.9              4.2            39
# 1      Doner King            3.9              4.2            39
# 2      Doner King            3.9              4.2            39
# 3      Doner King            3.9              4.2            39
# 4      Doner King            3.9              4.2            39
#
#    Delivery Votes   Cuisine  Place Name        City                 Item Name  \
# 0               0  Fast Food   Malakpet   Hyderabad       Platter Kebab Combo
# 1               0  Fast Food   Malakpet   Hyderabad   Chicken Rumali Shawarma
# 2               0  Fast Food   Malakpet   Hyderabad    Chicken Tandoori Salad
# 3               0  Fast Food   Malakpet   Hyderabad         Chicken BBQ Salad
# 4               0  Fast Food   Malakpet   Hyderabad  Special Doner Wrap Combo
#
#   Best Seller  Votes  Prices
# 0  BESTSELLER     84   249.0
# 1  BESTSELLER     45   129.0
# ...
